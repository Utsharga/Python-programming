# %%
from math import* 

question = input("enter the question number: ")

if question == "1" :
    v = input("enter the speed of the transverse waves in m/s: ")
    l = input("enter the length of the string in m : ")
    m = input("enter the mass of the string in kg: ")

    v = float(v)
    l = float(l)
    m = float(m)
    
    v = v / 1.0
    l = l / 1.0
    m = m / 1.0

    u = m / l
    T = (v**2)*(u)

    print ("the required tension is: " , T , "N")

    question = input("enter the question number: ")

if question == "2" :
    a = input("the equation should be in the form y = Acos(kx-wt): enter the A value in cm: ")
    k = input("enter the k value: ")
    w = input("enter the w value: ")

    a = float(a)
    k = float(k)
    w = float(w)
    
    phi = input("enter the phase angle in deg : ")

    phi = float(phi)
    a = a / 1.0
    k = k / 1.0
    w = w / 1.0
    phi = phi / 1.0

    d = (2*pi) / k

    c = (10 / phi)
    x = d*c

    print ("the position along the x-axis of point b is : " , x , "cm")

    question = input("enter the question number : ")

if question == "3":
    a = input("the equation should be in the form D(x,t) = Asin(kx-wt). enter the A value in m: ")
    k = input("enter the k value: ")
    w = input("enter the w value as positive: ")

    a = float(a)
    k = float(k)
    w = float(w)

    a = a / 1.0
    k = k /1.0
    w = w / 1.0

    wl = (2*pi) / k
    v = w/k

    print ("the amplitude of the wave is: " , a , "m")
    print ("the angular frequency of the wave is: ", w , "rad/s")
    print ("the angular wave number is: " , k , "rad/m")
    print ("the wavelength is : " , wl , "m")
    print ("the speed of the wave is: " , v , "m/s")

    question = input("enter the question number: ")

if question == "4" :
    T = input("enter the period of the wave in ms: ")
    v = input("enter the speed of the wave in m/s: ")
    x = input("enter the displacement at x = 0 and t = 0  in cm: ")
    vd = input("enter the downward speed of the wave in m/s: ")

    T = float(T)
    v = float(v)
    x = float(x)
    vd = float(vd)
    
    T = T * 1.0e-3
    v = v /1.0
    x = x / 100.0
    

    w = (2*pi) / T
    d = vd / (x*w)
    rad = atan(d)
    amp = x / cos(rad)
    phi = asin((-1*x)/amp)  + pi
    vmax = w*amp
    
    print ("the amplitude of the wave is: " , amp , "m")
    print ("the initial phase constant is: " , phi , "rad")
    print ("the maximum transverse speed of the string is: " , vmax , "m/s")

    question = input("enter the question number: ")

if question == "5" :
    l = input("enter the length of the string in m: ")
    m = input("enter the mass of string in g: ")
    f = input("enter the frequency of the string in Hz: ")
    n = input("enter the number of complete waves: ")
    pk = input("enter the peak-to-valley distance in cm: ")

    l = float(l)
    m = float(m)
    f = float(f)
    n = float(n)
    pk = float(pk)
    
    l = l / 1.0
    m = m / 1000.0
    f = f / 1.0
    amp = pk / 200.0
    w = 2*pi*f
    u = m / l
    n = n / 1.0

    wl = l / n
    v = f*wl
    P = (0.5)*(u)*(w**2)*(amp**2)*(v)

    print ("the power being supplied to the string is: " , P , "W")

    question = input("enter the question number: ")

if question == "6" :
    part = input("enter part (1,2,3,4): ")
    if part == "1" :
        w = input("the equation should be in form y = Acos(kx-wt + c). enter the magnitude w value: ")
        k = input("enter the k value: ")
        w = float(w)
        k = float(k)
        sign = input("what is the sign infront of w value (0 for negative and 1 for positive: ")
        w = w/ 1.0
        k = k /1.0
        if sign == "0" :
            v = w / k
            print ("the speed of the wave is: " , v ,"m/s")
        if sign == "1":
            v = w / k
            v = -1.0*v
            print ("the speed of the wave is: " , v ,"m/s")
        part = input("enter the part number(2,3,4): ")
    if part == "2" :
        w = input("the equation should be in form y = Acos(kx-wt - c). enter the magnitude w value: ")
        k = input("enter the k value: ")
        w = float(w)
        k = float(k)
        sign = input("what is the sign infront of w value (0 for negative and 1 for positive: ")
        w = w/ 1.0
        k = k /1.0
        if sign == "0" :
            v = w / k
            print ("the speed of the wave is: " , v ,"m/s")
        if sign == "1" :
            v = w / k
            v = -1.0*v
            print ("the speed of the wave is: " , v ,"m/s")

        part = input("enter the part number(3,4): ")

    if part == "3" :
        w = input("the equation should be in form y = Acos(wt-kx). enter the w value: ")
        k = input("enter the magnitude of the k value: ")
        w = float(w)
        k = float(k)
        sign = input("what is the sign infront of k value (0 for negative and 1 for positive: ")
        w = w/ 1.0
        k = k /1.0
        if sign == "0" :
            v = w / k
            print ("the speed of the wave is: " , v ,"m/s")
        if sign == "1" :
            v = w / k
            v = -1.0*v
            print ("the speed of the wave is: " , v ,"m/s")

        part = input("enter the part number(4) : ")

    if part == "4" :
        w = input("the equation should be in form y = Acos(wt-kx+n). enter the w value: ")
        k = input("enter the magnitude of the k value: ")
        w = float(w)
        k = float(k)
        sign = input("what is the sign infront of k value (0 for negative and 1 for positive: ")
        w = w/ 1.0
        k = k /1.0
        if sign == "0" :
            v = w / k
            print ("the speed of the wave is: " , v ,"m/s")
        if sign == "1" :
            v = w / k
            v = -1.0*v
            print ("the speed of the wave is: " , v ,"m/s")
    question = input("enter the question number: ")

if question == "7" :
    v1 = input("enter the wave speed of string in m/s: ")
    t1 = input("enter the tension of string in N: ")
    v2 = input("enter the required wave speed in m/s: ")

    v1 = float(v1)
    t1 = float(t1)
    v2 = float(v2)
    
    v1 = v1 / 1.0
    t1 = t1 / 1.0
    v2 = v2 / 1.0

    ratio = (v2**2) / (v1**2)

    t2 = ratio * t1

    print ("the required tension is: " , t2 , "N")
    question = input("enter the equestion number: ")

if question == "8" :
    w1 = input("enter the wavelength in the air, in nm: ")
    w2 = input("enter the wavelength in the solid, in nm: ")

    w1 = float(w1)
    w2 = float(w2)
    
    c = 3.0e8

    w1 = w1 * 1.0e-9
    w2 = w2 * 1.0e-9
    n = w1 / w2

    v = c / n

    f = v / w2

    print ("the speed of light in the solid is: " , v , "m/s")
    print ("the lighth's frequency in the solid is: " , f , "Hz")

    question = input("enter the question number: ")

if question == "9" :
    u = input("enter the linear density of the string in g/m: ")
    T = input("enter the tension on the string: ")
    f = input("enter the frequency: ")
    amp = input("enter the maximum displacement in mm: ")
    x = input("in the last part enter the x value in m: ")
    t = input("in the last part the t value in ms: ")

    u = float(u)
    T = float(T)
    f = float(f)
    amp = float(amp)
    x = float(x)
    t = float(t)
    
    u = u / 1000.0
    t = t / 1.0
    f = f / 1.0
    amp = amp / 1000.0
    x = x / 1.0
    t = t*1.0e-3
    T = T / 1.0

    v = sqrt(T / u)
    wl = v / f

    phi = 4.71

    w = 2*pi*f
    k = (2*pi) / wl

    Z = (k*x)
    Z1 = (w*t)
    Z2 = 4.71
    Z3 = Z - Z1 +Z2
    y = amp*sin(Z3)
    
   
    

    print ("the speed of the string is: " , v  , "m/s")
    print ("the wavelength is: " , wl , "m")
    print ("the amplitude of the wave is:" , amp , "m")
    print ("the phase constant is: " , phi , "rad")
    print ("the displacement is: ", y , "m . the answer is either the positive or negative value, you have 10 tries.")
# Out:
# enter the question number: 1
# enter the speed of the transverse waves in m/s: 51.1
# enter the length of the string in m : 4.65
# enter the mass of the string in kg: 0.0630
# the required tension is:  35.37768387096774 N
# enter the question number: 2
# the equation should be in the form y = Acos(kx-wt): enter the A value in cm: 17
# enter the k value: 0.148
# enter the w value: 71.5
# enter the phase angle in deg : 60
# the position along the x-axis of point b is :  7.075659129706741 cm
# enter the question number : 3
# the equation should be in the form D(x,t) = Asin(kx-wt). enter the A value in m: 0.180
# enter the k value: 0.590
# enter the w value as positive: 0.744
# the amplitude of the wave is:  0.18 m
# the angular frequency of the wave is:  0.744 rad/s
# the angular wave number is:  0.59 rad/m
# the wavelength is :  10.649466622338283 m
# the speed of the wave is:  1.2610169491525425 m/s
# enter the question number: 4
# enter the period of the wave in ms: 26.4
# enter the speed of the wave in m/s: 31.8
# enter the displacement at x = 0 and t = 0  in cm: 2.15
# enter the downward speed of the wave in m/s: 2.10
# the amplitude of the wave is:  0.023240159969261796 m
# the initial phase constant is:  1.9602339576409977 rad
# the maximum transverse speed of the string is:  5.531145138460944 m/s
# enter the question number: 5
# enter the length of the string in m:  6.47
# enter the mass of string in g: 197
# enter the frequency of the string in Hz: 52.0
# enter the number of complete waves: 3
# enter the peak-to-valley distance in cm: 16.7
# the power being supplied to the string is:  1270.7429073453195 W
# enter the question number: 6
# enter part (1,2,3,4): 1
# the equation should be in form y = Acos(kx-wt + c). enter the magnitude w value: 15.2
# enter the k value: 3.28
# what is the sign infront of w value (0 for negative and 1 for positive: 0
# the speed of the wave is:  4.634146341463414 m/s
# enter the part number(2,3,4): 2
# the equation should be in form y = Acos(kx-wt - c). enter the magnitude w value: 15.2
# enter the k value: 3.28
# what is the sign infront of w value (0 for negative and 1 for positive: 1
# the speed of the wave is:  -4.634146341463414 m/s
# enter the part number(3,4): 3
# the equation should be in form y = Acos(wt-kx). enter the w value: 16.3
# enter the magnitude of the k value: 2.00
# what is the sign infront of k value (0 for negative and 1 for positive: 0
# the speed of the wave is:  8.15 m/s
# enter the part number(4) : 4
# the equation should be in form y = Acos(wt-kx+n). enter the w value: 12.0
# enter the magnitude of the k value: 0.40
# what is the sign infront of k value (0 for negative and 1 for positive: 0
# the speed of the wave is:  30.0 m/s
# enter the question number: 7
# enter the wave speed of string in m/s: 145.0
# enter the tension of string in N: 66.3
# enter the required wave speed in m/s: 191.0
# the required tension is:  115.03877764565992 N
# enter the equestion number: 8
# enter the wavelength in the air, in nm:  644.8
# enter the wavelength in the solid, in nm: 401.5
# the speed of light in the solid is:  186802109.18114147 m/s
# the lighth's frequency in the solid is:  465260545905707.2 Hz
# enter the question number: 9
# enter the linear density of the string in g/m: 2.07
# enter the tension on the string: 18.4
# enter the frequency: 154.0
# enter the maximum displacement in mm: 0.111
# in the last part enter the x value in m: 0
# in the last part the t value in ms: 0
# the speed of the string is:  94.28090415820634 m/s
# the wavelength is:  0.6122136633649762 m
# the amplitude of the wave is: 0.000111 m
# the phase constant is:  4.71 rad
# the displacement is:  -0.00011099968324903669 m . the answer is either the positive or negative value, you have 10 tries.
